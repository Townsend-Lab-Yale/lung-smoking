# %%
import pandas as pd
from locations import merged_maf_file_name
from locations import location_gene_panels
from locations import all_panel_genes_file_name
from locations import location_data
from locations import gene_list_file
from locations import location_output
from locations import gene_coordinates_file
from count_combinations import compute_samples
from count_combinations import are_all_fluxes_computable
import os

# %%
db = pd.read_csv(merged_maf_file_name)
db = db[db['Variant_Classification'] != 'Silent']
db = db[~pd.isnull(db['Mutation'])]

# %%
db.groupby('Source').size()
# Out:
# Source
# Broad       51384
# FM-AD       10120
# Genie       41176
# MSK2015      6769
# MSK2017      2695
# MSK2018      1932
# OncoSG      63415
# TCGA       166830
# TSP          1015
# TracerX     33761
# dtype: int64

# %%
possible_sample_options = ['pan_data','smoking','nonsmoking']
samples_used = possible_sample_options[0]

# %%
db = pd.read_csv(merged_maf_file_name)

## Add panel information (should be in the importing_maf_data module)
panels_used = {key:pd.read_csv(
    os.path.join(location_gene_panels,
                 f"{key.lower()}_panels_used.txt")).set_index(
                     "Sample Identifier").to_dict()
    for key in ['Genie', 'MSK2017', 'MSK2018']}

for key in ['Genie', 'MSK2017', 'MSK2018']:
    db.loc[db['Source'] == key, 'Panel'] = db['Sample ID'].map(
        panels_used[key]['Sequence Assay ID' if key == 'Genie'
                         else 'Gene Panel'])

db.loc[db['Source'] == 'TSP', 'Panel'] = 'TSP'
db.loc[db['Source'] == 'FM-AD', 'Panel'] = 'FoundationOne'

# %%
#SETUP
db = db[db['Variant_Classification'] != 'Silent']
db = db[~pd.isnull(db['Mutation'])]


all_panel_genes = pd.read_csv(all_panel_genes_file_name)
included_panels = pd.unique(all_panel_genes['SEQ_ASSAY_ID'])

panels_to_remove_for_tp53_kras = []
for panel in included_panels:
    if ('TP53' not in all_panel_genes[
            all_panel_genes['SEQ_ASSAY_ID'] == panel]['Hugo_Symbol'].tolist()
        or 'KRAS' not in all_panel_genes[
            all_panel_genes['SEQ_ASSAY_ID'] == panel]['Hugo_Symbol'].tolist()):
        panels_to_remove_for_tp53_kras.append(panel)
db = db[~db['Panel'].isin(panels_to_remove_for_tp53_kras)]

smoking_sample_ids = pd.read_csv(
    os.path.join(location_data, 'smoking_sample_ids.txt'),
    header=None).iloc[:,0].tolist()
nonsmoking_sample_ids = pd.read_csv(
    os.path.join(location_data, 'nonsmoking_sample_ids.txt'),
    header=None).iloc[:,0].tolist()

if samples_used == 'smoking':
    db = db[db['Sample ID'].isin(smoking_sample_ids)]
elif samples_used == 'nonsmoking':
    db = db[db['Sample ID'].isin(nonsmoking_sample_ids)]

gene_list = list(pd.read_csv(gene_list_file, header=None)[0])

genes_with_uncomputable_fluxes = []
for i, gene in enumerate(gene_list[2:]):
    if i%50 == 0: print(f"(gene number {i}/{len(gene_list[2:])})")
    panels_to_remove = []
    for panel in included_panels:
        if gene not in all_panel_genes[
                all_panel_genes['SEQ_ASSAY_ID'] == panel]['Hugo_Symbol'].tolist():
            panels_to_remove.append(panel)
    subsetted_db = db[~db['Panel'].isin(panels_to_remove)]

    if not are_all_fluxes_computable(subsetted_db, mutations = ['TP53', 'KRAS', gene]):
        genes_with_uncomputable_fluxes.append(gene)

for gene in genes_with_uncomputable_fluxes:
    gene_list.remove(gene)
# Out:
# (gene number 0/1288)
# (gene number 1/1288)
# (gene number 2/1288)
# (gene number 3/1288)
# (gene number 4/1288)
# (gene number 5/1288)
# (gene number 6/1288)
# (gene number 7/1288)
# (gene number 8/1288)
# (gene number 9/1288)
# (gene number 10/1288)
# (gene number 11/1288)
# (gene number 12/1288)
# (gene number 13/1288)
# (gene number 14/1288)
# (gene number 15/1288)
# (gene number 16/1288)
# (gene number 17/1288)
# (gene number 18/1288)
# (gene number 19/1288)
# (gene number 20/1288)
# (gene number 21/1288)
# (gene number 22/1288)
# (gene number 23/1288)
# (gene number 24/1288)
# (gene number 25/1288)
# (gene number 26/1288)
# (gene number 27/1288)
# (gene number 28/1288)
# (gene number 29/1288)
# (gene number 30/1288)
# (gene number 31/1288)
# (gene number 32/1288)
# (gene number 33/1288)
# (gene number 34/1288)
# (gene number 35/1288)
# (gene number 36/1288)
# (gene number 37/1288)
# (gene number 38/1288)
# (gene number 39/1288)
# (gene number 40/1288)
# (gene number 41/1288)
# (gene number 42/1288)
# (gene number 43/1288)
# (gene number 44/1288)
# (gene number 45/1288)
# (gene number 46/1288)
# (gene number 47/1288)
# (gene number 48/1288)
# (gene number 49/1288)
# (gene number 50/1288)
# (gene number 51/1288)
# (gene number 52/1288)
# (gene number 53/1288)
# (gene number 54/1288)
# (gene number 55/1288)
# (gene number 56/1288)
# (gene number 57/1288)
# (gene number 58/1288)
# (gene number 59/1288)
# (gene number 60/1288)
# (gene number 61/1288)
# (gene number 62/1288)
# (gene number 63/1288)
# (gene number 64/1288)
# (gene number 65/1288)
# (gene number 66/1288)
# (gene number 67/1288)
# (gene number 68/1288)
# (gene number 69/1288)
# (gene number 70/1288)
# (gene number 71/1288)
# (gene number 72/1288)
# (gene number 73/1288)
# (gene number 74/1288)
# (gene number 75/1288)
# (gene number 76/1288)
# (gene number 77/1288)
# (gene number 78/1288)
# (gene number 79/1288)
# (gene number 80/1288)
# (gene number 81/1288)
# (gene number 82/1288)
# (gene number 83/1288)
# (gene number 84/1288)
# (gene number 85/1288)
# (gene number 86/1288)
# (gene number 87/1288)
# (gene number 88/1288)
# (gene number 89/1288)
# (gene number 90/1288)
# (gene number 91/1288)
# (gene number 92/1288)
# (gene number 93/1288)
# (gene number 94/1288)
# (gene number 95/1288)
# (gene number 96/1288)
# (gene number 97/1288)
# (gene number 98/1288)
# (gene number 99/1288)
# (gene number 100/1288)
# (gene number 101/1288)
# (gene number 102/1288)
# (gene number 103/1288)
# (gene number 104/1288)
# (gene number 105/1288)
# (gene number 106/1288)
# (gene number 107/1288)
# (gene number 108/1288)
# (gene number 109/1288)
# (gene number 110/1288)
# (gene number 111/1288)
# (gene number 112/1288)
# (gene number 113/1288)
# (gene number 114/1288)
# (gene number 115/1288)
# (gene number 116/1288)
# (gene number 117/1288)
# (gene number 118/1288)
# (gene number 119/1288)
# (gene number 120/1288)
# (gene number 121/1288)
# (gene number 122/1288)
# (gene number 123/1288)
# (gene number 124/1288)
# (gene number 125/1288)
# (gene number 126/1288)
# (gene number 127/1288)
# (gene number 128/1288)
# (gene number 129/1288)
# (gene number 130/1288)
# (gene number 131/1288)
# (gene number 132/1288)
# (gene number 133/1288)
# (gene number 134/1288)
# (gene number 135/1288)
# (gene number 136/1288)
# (gene number 137/1288)
# (gene number 138/1288)
# (gene number 139/1288)
# (gene number 140/1288)
# (gene number 141/1288)
# (gene number 142/1288)
# (gene number 143/1288)
# (gene number 144/1288)
# (gene number 145/1288)
# (gene number 146/1288)
# (gene number 147/1288)
# (gene number 148/1288)
# (gene number 149/1288)
# (gene number 150/1288)
# (gene number 151/1288)
# (gene number 152/1288)
# (gene number 153/1288)
# (gene number 154/1288)
# (gene number 155/1288)
# (gene number 156/1288)
# (gene number 157/1288)
# (gene number 158/1288)
# (gene number 159/1288)
# (gene number 160/1288)
# (gene number 161/1288)
# (gene number 162/1288)
# (gene number 163/1288)
# (gene number 164/1288)
# (gene number 165/1288)
# (gene number 166/1288)
# (gene number 167/1288)
# (gene number 168/1288)
# (gene number 169/1288)
# (gene number 170/1288)
# (gene number 171/1288)
# (gene number 172/1288)
# (gene number 173/1288)
# (gene number 174/1288)
# (gene number 175/1288)
# (gene number 176/1288)
# (gene number 177/1288)
# (gene number 178/1288)
# (gene number 179/1288)
# (gene number 180/1288)
# (gene number 181/1288)
# (gene number 182/1288)
# (gene number 183/1288)
# (gene number 184/1288)
# (gene number 185/1288)
# (gene number 186/1288)
# (gene number 187/1288)
# (gene number 188/1288)
# (gene number 189/1288)
# (gene number 190/1288)
# (gene number 191/1288)
# (gene number 192/1288)
# (gene number 193/1288)
# (gene number 194/1288)
# (gene number 195/1288)
# (gene number 196/1288)
# (gene number 197/1288)
# (gene number 198/1288)
# (gene number 199/1288)
# (gene number 200/1288)
# (gene number 201/1288)
# (gene number 202/1288)
# (gene number 203/1288)
# (gene number 204/1288)
# (gene number 205/1288)
# (gene number 206/1288)
# (gene number 207/1288)
# (gene number 208/1288)
# (gene number 209/1288)
# (gene number 210/1288)
# (gene number 211/1288)
# (gene number 212/1288)
# (gene number 213/1288)
# (gene number 214/1288)
# (gene number 215/1288)
# (gene number 216/1288)
# (gene number 217/1288)
# (gene number 218/1288)
# (gene number 219/1288)
# (gene number 220/1288)
# (gene number 221/1288)
# (gene number 222/1288)
# (gene number 223/1288)
# (gene number 224/1288)
# (gene number 225/1288)
# (gene number 226/1288)
# (gene number 227/1288)
# (gene number 228/1288)
# (gene number 229/1288)
# (gene number 230/1288)
# (gene number 231/1288)
# (gene number 232/1288)
# (gene number 233/1288)
# (gene number 234/1288)
# (gene number 235/1288)
# (gene number 236/1288)
# (gene number 237/1288)
# (gene number 238/1288)
# (gene number 239/1288)
# (gene number 240/1288)
# (gene number 241/1288)
# (gene number 242/1288)
# (gene number 243/1288)
# (gene number 244/1288)
# (gene number 245/1288)
# (gene number 246/1288)
# (gene number 247/1288)
# (gene number 248/1288)
# (gene number 249/1288)
# (gene number 250/1288)
# (gene number 251/1288)
# (gene number 252/1288)
# (gene number 253/1288)
# (gene number 254/1288)
# (gene number 255/1288)
# (gene number 256/1288)
# (gene number 257/1288)
# (gene number 258/1288)
# (gene number 259/1288)
# (gene number 260/1288)
# (gene number 261/1288)
# (gene number 262/1288)
# (gene number 263/1288)
# (gene number 264/1288)
# (gene number 265/1288)
# (gene number 266/1288)
# (gene number 267/1288)
# (gene number 268/1288)
# (gene number 269/1288)
# (gene number 270/1288)
# (gene number 271/1288)
# (gene number 272/1288)
# (gene number 273/1288)
# (gene number 274/1288)
# (gene number 275/1288)
# (gene number 276/1288)
# (gene number 277/1288)
# (gene number 278/1288)
# (gene number 279/1288)
# (gene number 280/1288)
# (gene number 281/1288)
# (gene number 282/1288)
# (gene number 283/1288)
# (gene number 284/1288)
# (gene number 285/1288)
# (gene number 286/1288)
# (gene number 287/1288)
# (gene number 288/1288)
# (gene number 289/1288)
# (gene number 290/1288)
# (gene number 291/1288)
# (gene number 292/1288)
# (gene number 293/1288)
# (gene number 294/1288)
# (gene number 295/1288)
# (gene number 296/1288)
# (gene number 297/1288)
# (gene number 298/1288)
# (gene number 299/1288)
# (gene number 300/1288)
# (gene number 301/1288)
# (gene number 302/1288)
# (gene number 303/1288)
# (gene number 304/1288)
# (gene number 305/1288)
# (gene number 306/1288)
# (gene number 307/1288)
# (gene number 308/1288)
# (gene number 309/1288)
# (gene number 310/1288)
# (gene number 311/1288)
# (gene number 312/1288)
# (gene number 313/1288)
# (gene number 314/1288)
# (gene number 315/1288)
# (gene number 316/1288)
# (gene number 317/1288)
# (gene number 318/1288)
# (gene number 319/1288)
# (gene number 320/1288)
# (gene number 321/1288)
# (gene number 322/1288)
# (gene number 323/1288)
# (gene number 324/1288)
# (gene number 325/1288)
# (gene number 326/1288)
# (gene number 327/1288)
# (gene number 328/1288)
# (gene number 329/1288)
# (gene number 330/1288)
# (gene number 331/1288)
# (gene number 332/1288)
# (gene number 333/1288)
# (gene number 334/1288)
# (gene number 335/1288)
# (gene number 336/1288)
# (gene number 337/1288)
# (gene number 338/1288)
# (gene number 339/1288)
# (gene number 340/1288)
# (gene number 341/1288)
# (gene number 342/1288)
# (gene number 343/1288)
# (gene number 344/1288)
# (gene number 345/1288)
# (gene number 346/1288)
# (gene number 347/1288)
# (gene number 348/1288)
# (gene number 349/1288)
# (gene number 350/1288)
# (gene number 351/1288)
# (gene number 352/1288)
# (gene number 353/1288)
# (gene number 354/1288)
# (gene number 355/1288)
# (gene number 356/1288)
# (gene number 357/1288)
# (gene number 358/1288)
# (gene number 359/1288)
# (gene number 360/1288)
# (gene number 361/1288)
# (gene number 362/1288)
# (gene number 363/1288)
# (gene number 364/1288)
# (gene number 365/1288)
# (gene number 366/1288)
# (gene number 367/1288)
# (gene number 368/1288)
# (gene number 369/1288)
# (gene number 370/1288)
# (gene number 371/1288)
# (gene number 372/1288)
# (gene number 373/1288)
# (gene number 374/1288)
# (gene number 375/1288)
# (gene number 376/1288)
# (gene number 377/1288)
# (gene number 378/1288)
# (gene number 379/1288)
# (gene number 380/1288)
# (gene number 381/1288)
# (gene number 382/1288)
# (gene number 383/1288)
# (gene number 384/1288)
# (gene number 385/1288)
# (gene number 386/1288)
# (gene number 387/1288)
# (gene number 388/1288)
# (gene number 389/1288)
# (gene number 390/1288)
# (gene number 391/1288)
# (gene number 392/1288)
# (gene number 393/1288)
# (gene number 394/1288)
# (gene number 395/1288)
# (gene number 396/1288)
# (gene number 397/1288)
# (gene number 398/1288)
# (gene number 399/1288)
# (gene number 400/1288)
# (gene number 401/1288)
# (gene number 402/1288)
# (gene number 403/1288)
# (gene number 404/1288)
# (gene number 405/1288)
# (gene number 406/1288)
# (gene number 407/1288)
# (gene number 408/1288)
# (gene number 409/1288)
# (gene number 410/1288)
# (gene number 411/1288)
# (gene number 412/1288)
# (gene number 413/1288)
# (gene number 414/1288)
# (gene number 415/1288)
# (gene number 416/1288)
# (gene number 417/1288)
# (gene number 418/1288)
# (gene number 419/1288)
# (gene number 420/1288)
# (gene number 421/1288)
# (gene number 422/1288)
# (gene number 423/1288)
# (gene number 424/1288)
# (gene number 425/1288)
# (gene number 426/1288)
# (gene number 427/1288)
# (gene number 428/1288)
# (gene number 429/1288)
# (gene number 430/1288)
# (gene number 431/1288)
# (gene number 432/1288)
# (gene number 433/1288)
# (gene number 434/1288)
# (gene number 435/1288)
# (gene number 436/1288)
# (gene number 437/1288)
# (gene number 438/1288)
# (gene number 439/1288)
# (gene number 440/1288)
# (gene number 441/1288)
# (gene number 442/1288)
# (gene number 443/1288)
# (gene number 444/1288)
# (gene number 445/1288)
# (gene number 446/1288)
# (gene number 447/1288)
# (gene number 448/1288)
# (gene number 449/1288)
# (gene number 450/1288)
# (gene number 451/1288)
# (gene number 452/1288)
# (gene number 453/1288)
# (gene number 454/1288)
# (gene number 455/1288)
# (gene number 456/1288)
# (gene number 457/1288)
# (gene number 458/1288)
# (gene number 459/1288)
# (gene number 460/1288)
# (gene number 461/1288)
# (gene number 462/1288)
# (gene number 463/1288)
# (gene number 464/1288)
# (gene number 465/1288)
# (gene number 466/1288)
# (gene number 467/1288)
# (gene number 468/1288)
# (gene number 469/1288)
# (gene number 470/1288)
# (gene number 471/1288)
# (gene number 472/1288)
# (gene number 473/1288)
# (gene number 474/1288)
# (gene number 475/1288)
# (gene number 476/1288)
# (gene number 477/1288)
# (gene number 478/1288)
# (gene number 479/1288)
# (gene number 480/1288)
# (gene number 481/1288)
# (gene number 482/1288)
# (gene number 483/1288)
# (gene number 484/1288)
# (gene number 485/1288)
# (gene number 486/1288)
# (gene number 487/1288)
# (gene number 488/1288)
# (gene number 489/1288)
# (gene number 490/1288)
# (gene number 491/1288)
# (gene number 492/1288)
# (gene number 493/1288)
# (gene number 494/1288)
# (gene number 495/1288)
# (gene number 496/1288)
# (gene number 497/1288)
# (gene number 498/1288)
# (gene number 499/1288)
# (gene number 500/1288)
# (gene number 501/1288)
# (gene number 502/1288)
# (gene number 503/1288)
# (gene number 504/1288)
# (gene number 505/1288)
# (gene number 506/1288)
# (gene number 507/1288)
# (gene number 508/1288)
# (gene number 509/1288)
# (gene number 510/1288)
# (gene number 511/1288)
# (gene number 512/1288)
# (gene number 513/1288)
# (gene number 514/1288)
# (gene number 515/1288)
# (gene number 516/1288)
# (gene number 517/1288)
# (gene number 518/1288)
# (gene number 519/1288)
# (gene number 520/1288)
# (gene number 521/1288)
# (gene number 522/1288)
# (gene number 523/1288)
# (gene number 524/1288)
# (gene number 525/1288)
# (gene number 526/1288)
# (gene number 527/1288)
# (gene number 528/1288)
# (gene number 529/1288)
# (gene number 530/1288)
# (gene number 531/1288)
# (gene number 532/1288)
# (gene number 533/1288)
# (gene number 534/1288)
# (gene number 535/1288)
# (gene number 536/1288)
# (gene number 537/1288)
# (gene number 538/1288)
# (gene number 539/1288)
# (gene number 540/1288)
# (gene number 541/1288)
# (gene number 542/1288)
# (gene number 543/1288)
# (gene number 544/1288)
# (gene number 545/1288)
# (gene number 546/1288)
# (gene number 547/1288)
# (gene number 548/1288)
# (gene number 549/1288)
# (gene number 550/1288)
# (gene number 551/1288)
# (gene number 552/1288)
# (gene number 553/1288)
# (gene number 554/1288)
# (gene number 555/1288)
# (gene number 556/1288)
# (gene number 557/1288)
# (gene number 558/1288)
# (gene number 559/1288)
# (gene number 560/1288)
# (gene number 561/1288)
# (gene number 562/1288)
# (gene number 563/1288)
# (gene number 564/1288)
# (gene number 565/1288)
# (gene number 566/1288)
# (gene number 567/1288)
# (gene number 568/1288)
# (gene number 569/1288)
# (gene number 570/1288)
# (gene number 571/1288)
# (gene number 572/1288)
# (gene number 573/1288)
# (gene number 574/1288)
# (gene number 575/1288)
# (gene number 576/1288)
# (gene number 577/1288)
# (gene number 578/1288)
# (gene number 579/1288)
# (gene number 580/1288)
# (gene number 581/1288)
# (gene number 582/1288)
# (gene number 583/1288)
# (gene number 584/1288)
# (gene number 585/1288)
# (gene number 586/1288)
# (gene number 587/1288)
# (gene number 588/1288)
# (gene number 589/1288)
# (gene number 590/1288)
# (gene number 591/1288)
# (gene number 592/1288)
# (gene number 593/1288)
# (gene number 594/1288)
# (gene number 595/1288)
# (gene number 596/1288)
# (gene number 597/1288)
# (gene number 598/1288)
# (gene number 599/1288)
# (gene number 600/1288)
# (gene number 601/1288)
# (gene number 602/1288)
# (gene number 603/1288)
# (gene number 604/1288)
# (gene number 605/1288)
# (gene number 606/1288)
# (gene number 607/1288)
# (gene number 608/1288)
# (gene number 609/1288)
# (gene number 610/1288)
# (gene number 611/1288)
# (gene number 612/1288)
# (gene number 613/1288)
# (gene number 614/1288)
# (gene number 615/1288)
# (gene number 616/1288)
# (gene number 617/1288)
# (gene number 618/1288)
# (gene number 619/1288)
# (gene number 620/1288)
# (gene number 621/1288)
# (gene number 622/1288)
# (gene number 623/1288)
# (gene number 624/1288)
# (gene number 625/1288)
# (gene number 626/1288)
# (gene number 627/1288)
# (gene number 628/1288)
# (gene number 629/1288)
# (gene number 630/1288)
# (gene number 631/1288)
# (gene number 632/1288)
# (gene number 633/1288)
# (gene number 634/1288)
# (gene number 635/1288)
# (gene number 636/1288)
# (gene number 637/1288)
# (gene number 638/1288)
# (gene number 639/1288)
# (gene number 640/1288)
# (gene number 641/1288)
# (gene number 642/1288)
# (gene number 643/1288)
# (gene number 644/1288)
# (gene number 645/1288)
# (gene number 646/1288)
# (gene number 647/1288)
# (gene number 648/1288)
# (gene number 649/1288)
# (gene number 650/1288)
# (gene number 651/1288)
# (gene number 652/1288)
# (gene number 653/1288)
# (gene number 654/1288)
# (gene number 655/1288)
# (gene number 656/1288)
# (gene number 657/1288)
# (gene number 658/1288)
# (gene number 659/1288)
# (gene number 660/1288)
# (gene number 661/1288)
# (gene number 662/1288)
# (gene number 663/1288)
# (gene number 664/1288)
# (gene number 665/1288)
# (gene number 666/1288)
# (gene number 667/1288)
# (gene number 668/1288)
# (gene number 669/1288)
# (gene number 670/1288)
# (gene number 671/1288)
# (gene number 672/1288)
# (gene number 673/1288)
# (gene number 674/1288)
# (gene number 675/1288)
# (gene number 676/1288)
# (gene number 677/1288)
# (gene number 678/1288)
# (gene number 679/1288)
# (gene number 680/1288)
# (gene number 681/1288)
# (gene number 682/1288)
# (gene number 683/1288)
# (gene number 684/1288)
# (gene number 685/1288)
# (gene number 686/1288)
# (gene number 687/1288)
# (gene number 688/1288)
# (gene number 689/1288)
# (gene number 690/1288)
# (gene number 691/1288)
# (gene number 692/1288)
# (gene number 693/1288)
# (gene number 694/1288)
# (gene number 695/1288)
# (gene number 696/1288)
# (gene number 697/1288)
# (gene number 698/1288)
# (gene number 699/1288)
# (gene number 700/1288)
# (gene number 701/1288)
# (gene number 702/1288)
# (gene number 703/1288)
# (gene number 704/1288)
# (gene number 705/1288)
# (gene number 706/1288)
# (gene number 707/1288)
# (gene number 708/1288)
# (gene number 709/1288)
# (gene number 710/1288)
# (gene number 711/1288)
# (gene number 712/1288)
# (gene number 713/1288)
# (gene number 714/1288)
# (gene number 715/1288)
# (gene number 716/1288)
# (gene number 717/1288)
# (gene number 718/1288)
# (gene number 719/1288)
# (gene number 720/1288)
# (gene number 721/1288)
# (gene number 722/1288)
# (gene number 723/1288)
# (gene number 724/1288)
# (gene number 725/1288)
# (gene number 726/1288)
# (gene number 727/1288)
# (gene number 728/1288)
# (gene number 729/1288)
# (gene number 730/1288)
# (gene number 731/1288)
# (gene number 732/1288)
# (gene number 733/1288)
# (gene number 734/1288)
# (gene number 735/1288)
# (gene number 736/1288)
# (gene number 737/1288)
# (gene number 738/1288)
# (gene number 739/1288)
# (gene number 740/1288)
# (gene number 741/1288)
# (gene number 742/1288)
# (gene number 743/1288)
# (gene number 744/1288)
# (gene number 745/1288)
# (gene number 746/1288)
# (gene number 747/1288)
# (gene number 748/1288)
# (gene number 749/1288)
# (gene number 750/1288)
# (gene number 751/1288)
# (gene number 752/1288)
# (gene number 753/1288)
# (gene number 754/1288)
# (gene number 755/1288)
# (gene number 756/1288)
# (gene number 757/1288)
# (gene number 758/1288)
# (gene number 759/1288)
# (gene number 760/1288)
# (gene number 761/1288)
# (gene number 762/1288)
# (gene number 763/1288)
# (gene number 764/1288)
# (gene number 765/1288)
# (gene number 766/1288)
# (gene number 767/1288)
# (gene number 768/1288)
# (gene number 769/1288)
# (gene number 770/1288)
# (gene number 771/1288)
# (gene number 772/1288)
# (gene number 773/1288)
# (gene number 774/1288)
# (gene number 775/1288)
# (gene number 776/1288)
# (gene number 777/1288)
# (gene number 778/1288)
# (gene number 779/1288)
# (gene number 780/1288)
# (gene number 781/1288)
# (gene number 782/1288)
# (gene number 783/1288)
# (gene number 784/1288)
# (gene number 785/1288)
# (gene number 786/1288)
# (gene number 787/1288)
# (gene number 788/1288)
# (gene number 789/1288)
# (gene number 790/1288)
# (gene number 791/1288)
# (gene number 792/1288)
# (gene number 793/1288)
# (gene number 794/1288)
# (gene number 795/1288)
# (gene number 796/1288)
# (gene number 797/1288)
# (gene number 798/1288)
# (gene number 799/1288)
# (gene number 800/1288)
# (gene number 801/1288)
# (gene number 802/1288)
# (gene number 803/1288)
# (gene number 804/1288)
# (gene number 805/1288)
# (gene number 806/1288)
# (gene number 807/1288)
# (gene number 808/1288)
# (gene number 809/1288)
# (gene number 810/1288)
# (gene number 811/1288)
# (gene number 812/1288)
# (gene number 813/1288)
# (gene number 814/1288)
# (gene number 815/1288)
# (gene number 816/1288)
# (gene number 817/1288)
# (gene number 818/1288)
# (gene number 819/1288)
# (gene number 820/1288)
# (gene number 821/1288)
# (gene number 822/1288)
# (gene number 823/1288)
# (gene number 824/1288)
# (gene number 825/1288)
# (gene number 826/1288)
# (gene number 827/1288)
# (gene number 828/1288)
# (gene number 829/1288)
# (gene number 830/1288)
# (gene number 831/1288)
# (gene number 832/1288)
# (gene number 833/1288)
# (gene number 834/1288)
# (gene number 835/1288)
# (gene number 836/1288)
# (gene number 837/1288)
# (gene number 838/1288)
# (gene number 839/1288)
# (gene number 840/1288)
# (gene number 841/1288)
# (gene number 842/1288)
# (gene number 843/1288)
# (gene number 844/1288)
# (gene number 845/1288)
# (gene number 846/1288)
# (gene number 847/1288)
# (gene number 848/1288)
# (gene number 849/1288)
# (gene number 850/1288)
# (gene number 851/1288)
# (gene number 852/1288)
# (gene number 853/1288)
# (gene number 854/1288)
# (gene number 855/1288)
# (gene number 856/1288)
# (gene number 857/1288)
# (gene number 858/1288)
# (gene number 859/1288)
# (gene number 860/1288)
# (gene number 861/1288)
# (gene number 862/1288)
# (gene number 863/1288)
# (gene number 864/1288)
# (gene number 865/1288)
# (gene number 866/1288)
# (gene number 867/1288)
# (gene number 868/1288)
# (gene number 869/1288)
# (gene number 870/1288)
# (gene number 871/1288)
# (gene number 872/1288)
# (gene number 873/1288)
# (gene number 874/1288)
# (gene number 875/1288)
# (gene number 876/1288)
# (gene number 877/1288)
# (gene number 878/1288)
# (gene number 879/1288)
# (gene number 880/1288)
# (gene number 881/1288)
# (gene number 882/1288)
# (gene number 883/1288)
# (gene number 884/1288)
# (gene number 885/1288)
# (gene number 886/1288)
# (gene number 887/1288)
# (gene number 888/1288)
# (gene number 889/1288)
# (gene number 890/1288)
# (gene number 891/1288)
# (gene number 892/1288)
# (gene number 893/1288)
# (gene number 894/1288)
# (gene number 895/1288)
# (gene number 896/1288)
# (gene number 897/1288)
# (gene number 898/1288)
# (gene number 899/1288)
# (gene number 900/1288)
# (gene number 901/1288)
# (gene number 902/1288)
# (gene number 903/1288)
# (gene number 904/1288)
# (gene number 905/1288)
# (gene number 906/1288)
# (gene number 907/1288)
# (gene number 908/1288)
# (gene number 909/1288)
# (gene number 910/1288)
# (gene number 911/1288)
# (gene number 912/1288)
# (gene number 913/1288)
# (gene number 914/1288)
# (gene number 915/1288)
# (gene number 916/1288)
# (gene number 917/1288)
# (gene number 918/1288)
# (gene number 919/1288)
# (gene number 920/1288)
# (gene number 921/1288)
# (gene number 922/1288)
# (gene number 923/1288)
# (gene number 924/1288)
# (gene number 925/1288)
# (gene number 926/1288)
# (gene number 927/1288)
# (gene number 928/1288)
# (gene number 929/1288)
# (gene number 930/1288)
# (gene number 931/1288)
# (gene number 932/1288)
# (gene number 933/1288)
# (gene number 934/1288)
# (gene number 935/1288)
# (gene number 936/1288)
# (gene number 937/1288)
# (gene number 938/1288)
# (gene number 939/1288)
# (gene number 940/1288)
# (gene number 941/1288)
# (gene number 942/1288)
# (gene number 943/1288)
# (gene number 944/1288)
# (gene number 945/1288)
# (gene number 946/1288)
# (gene number 947/1288)
# (gene number 948/1288)
# (gene number 949/1288)
# (gene number 950/1288)
# (gene number 951/1288)
# (gene number 952/1288)
# (gene number 953/1288)
# (gene number 954/1288)
# (gene number 955/1288)
# (gene number 956/1288)
# (gene number 957/1288)
# (gene number 958/1288)
# (gene number 959/1288)
# (gene number 960/1288)
# (gene number 961/1288)
# (gene number 962/1288)
# (gene number 963/1288)
# (gene number 964/1288)
# (gene number 965/1288)
# (gene number 966/1288)
# (gene number 967/1288)
# (gene number 968/1288)
# (gene number 969/1288)
# (gene number 970/1288)
# (gene number 971/1288)
# (gene number 972/1288)
# (gene number 973/1288)
# (gene number 974/1288)
# (gene number 975/1288)
# (gene number 976/1288)
# (gene number 977/1288)
# (gene number 978/1288)
# (gene number 979/1288)
# (gene number 980/1288)
# (gene number 981/1288)
# (gene number 982/1288)
# (gene number 983/1288)
# (gene number 984/1288)
# (gene number 985/1288)
# (gene number 986/1288)
# (gene number 987/1288)
# (gene number 988/1288)
# (gene number 989/1288)
# (gene number 990/1288)
# (gene number 991/1288)
# (gene number 992/1288)
# (gene number 993/1288)
# (gene number 994/1288)
# (gene number 995/1288)
# (gene number 996/1288)
# (gene number 997/1288)
# (gene number 998/1288)
# (gene number 999/1288)
# (gene number 1000/1288)
# (gene number 1001/1288)
# (gene number 1002/1288)
# (gene number 1003/1288)
# (gene number 1004/1288)
# (gene number 1005/1288)
# (gene number 1006/1288)
# (gene number 1007/1288)
# (gene number 1008/1288)
# (gene number 1009/1288)
# (gene number 1010/1288)
# (gene number 1011/1288)
# (gene number 1012/1288)
# (gene number 1013/1288)
# (gene number 1014/1288)
# (gene number 1015/1288)
# (gene number 1016/1288)
# (gene number 1017/1288)
# (gene number 1018/1288)
# (gene number 1019/1288)
# (gene number 1020/1288)
# (gene number 1021/1288)
# (gene number 1022/1288)
# (gene number 1023/1288)
# (gene number 1024/1288)
# (gene number 1025/1288)
# (gene number 1026/1288)
# (gene number 1027/1288)

# %%
def compute_pts_per_single_mutation(data, mutation=None):
    pts_per_mutation = [len(set(
        data[
            (data['Start_Position'] >= genes.loc[mutation, 'start']) &
            (data['Start_Position'] <= genes.loc[mutation, 'end']) &
            (data['Chromosome'] == genes.loc[mutation, 'chromosome'])]
        ['Sample ID']))]

    return pts_per_mutation

# %%
genes = pd.read_csv(gene_coordinates_file, index_col='gene')

patients_per_gene = dict()
for i, gene in enumerate(gene_list[2:]):
    panels_to_remove = []
    for panel in included_panels:
        if gene not in all_panel_genes[
                all_panel_genes['SEQ_ASSAY_ID'] == panel]['Hugo_Symbol'].tolist():
            panels_to_remove.append(panel)
    subsetted_db = db[~db['Panel'].isin(panels_to_remove)]
    patients_per_gene[gene] = compute_pts_per_single_mutation(subsetted_db, mutation=gene)

# %%
patients_per_gene = {k:v[0] for k,v in patients_per_gene.items()}

# %%
patients_per_gene = pd.DataFrame.from_dict(patients_per_gene, orient = 'index').rename(columns = {0:'num_patients'})

# %%
patients_per_gene.to_csv(location_output + '/patients_per_gene.csv')
